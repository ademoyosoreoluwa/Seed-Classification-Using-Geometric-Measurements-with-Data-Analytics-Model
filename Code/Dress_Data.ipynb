# %%
import pandas as pd
import numpy as np
from pandas.core.arrays.sparse import SparseArray as _SparseArray

# %%
wheatData = pd.read_csv('/Users/apple/Desktop/Data Science Foundation/Course Work/WheatData(1).csv')

# %%
wheatData
# Out:
#       area  perimeter  compactness  length of kernel  width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      asymmetry coefficient  length of kernel groove wheatLabel
# 0                    2.221                    5.220       Kama
# ...

# %%
wheatData.info()
wheatData.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   area                     210 non-null    float64
#  1   perimeter                210 non-null    float64
#  2   compactness              210 non-null    float64
#  3   length of kernel         210 non-null    float64
#  4   width of kernel          210 non-null    float64
#  5   asymmetry coefficient    210 non-null    float64
#  6   length of kernel groove  210 non-null    float64
#  7   wheatLabel               210 non-null    object
# dtypes: float64(7), object(1)
# memory usage: 13.2+ KB
# (210, 8)

# %%
wheatData.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'length of kernel',
#        'width of kernel', 'asymmetry coefficient', 'length of kernel groove',
#        'wheatLabel'],
#       dtype='object')

# %%
wheatData.describe().transpose()
# Out:
#                          count       mean       std      min       25%  \
# area                     210.0  14.847524  2.909699  10.5900  12.27000
# perimeter                210.0  14.559286  1.305959  12.4100  13.45000
# compactness              210.0   0.870999  0.023629   0.8081   0.85690
# length of kernel         210.0   5.628533  0.443063   4.8990   5.26225
# width of kernel          210.0   3.258605  0.377714   2.6300   2.94400
# asymmetry coefficient    210.0   3.700201  1.503557   0.7651   2.56150
# length of kernel groove  210.0   5.408071  0.491480   4.5190   5.04500
#
#                               50%        75%      max
# area                     14.35500  17.305000  21.1800
# perimeter                14.32000  15.715000  17.2500
# compactness               0.87345   0.887775   0.9183
# length of kernel          5.52350   5.979750   6.6750
# width of kernel           3.23700   3.561750   4.0330
# asymmetry coefficient     3.59900   4.768750   8.4560
# ...

# %%
=== Summary Stratified cross-validation ===
Correctly Classified Instances         192        91.4286 %
Incorrectly Classified Instances        18         8.5714 %
Kappa statistic                          0.8714
Mean absolute error                      0.0633
Root mean squared error                  0.2269
Relative absolute error                 14.2521 %
Root relative squared error             48.1429 %
Total Number of Instances              210     
=== Detailed Accuracy By Class ===
TP Rate FP Rate Precision Recall  F-Measure MCC   ROC Area PRC Area Class
0.857   0.057   0.882     0.857   0.870     0.806  0.969   0.942    Kama
0.943   0.021   0.957     0.943   0.950     0.925  0.994   0.990    Rosa 
0.943   0.050   0.904     0.943   0.923     0.884  0.990   0.980  Canadian
Weighted Avg.    
0.914   0.043   0.914     0.914   0.914     0.872  0.985   0.971     
Confusion Matrix
 a  b  c   <-- classified as
60  3  7 | a = Kama
 4 66  0 |  b = Rosa 
 4  0 66 |  c = Canadian

# %%
=== Summary Stratified cross-validation ===
Correctly Classified Instances         188         89.5238 %
Incorrectly Classified Instances        22         10.4762 %
Kappa statistic                          0.8429
Mean absolute error                      0.0698
Root mean squared error                  0.2643
Relative absolute error                 15.7143 %
Root relative squared error             56.0612 %
Total Number of Instances              210     
=== Detailed Accuracy By Class ===
TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
0.871    0.093    0.824      0.871    0.847      0.768    0.889     0.761     Kama
0.957    0.021    0.957      0.957    0.957      0.936    0.968     0.930     Rosa 
0.857    0.043    0.909      0.857    0.882      0.827    0.907     0.827   Canadian
Weighted Avg.    
0.895    0.052    0.897      0.895    0.896      0.844    0.921     0.839     
=== Confusion Matrix ===
 a  b  c   <-- classified as
61  3  6 |  a = Kama
 3 67  0 |  b = Rosa 
10  0 60 |  c = Canadian

# %%
=== Summary Stratified cross-validation ===
Correctly Classified Instances         198         94.2857 %
Incorrectly Classified Instances        12          5.7143 %
Kappa statistic                          0.9143
Mean absolute error                      0.0444
Root mean squared error                  0.1938
Relative absolute error                 10      %
Root relative squared error             41.1089 %
Total Number of Instances              210     
=== Detailed Accuracy By Class ===
TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
0.886    0.029    0.939      0.886    0.912      0.870    0.929     0.870     Kama
0.957    0.014    0.971      0.957    0.964      0.946    0.971     0.944     Rosa 
0.986    0.043    0.920      0.986    0.952      0.928    0.971     0.912   Canadian
Weighted Avg.    
0.943    0.029    0.943      0.943    0.943      0.915    0.957     0.908     
=== Confusion Matrix ===
 a  b  c   <-- classified as
62  2  6 |  a = Kama
 3 67  0 |  b = Rosa 
 1  0 69 |  c = Canadian

# %%
=== Summary Stratified cross-validation ===
Correctly Classified Instances         197        93.8095 %
Incorrectly Classified Instances        13         6.1905 %
Kappa statistic                          0.9071
Mean absolute error                      0.236 
Root mean squared error                  0.2964
Relative absolute error                 53.0952 %
Root relative squared error             62.868  %
Total Number of Instances              210     
=== Detailed Accuracy By Class ===
TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
0.900    0.043    0.913      0.900    0.906      0.860    0.929     0.855     Kama
0.971    0.021    0.958      0.971    0.965      0.947    0.986     0.950     Rosa 
0.943    0.029    0.943      0.943    0.943      0.914    0.978     0.926   Canadian
Weighted Avg.    
0.938    0.031    0.938      0.938    0.938      0.907    0.964     0.910     
=== Confusion Matrix ===
 a  b  c   <-- classified as
63  3  4 |  a = Kama
 2 68  0 |  b = Rosa 
 4  0 66 |  c = Canadian

# %%
=== Summary Stratified cross-validation ===
Correctly Classified Instances         200       95.2381 %
Incorrectly Classified Instances        10        4.7619 %
Kappa statistic                          0.9286
Mean absolute error                      0.0411
Root mean squared error                  0.1507
Relative absolute error                  9.2585 %
Root relative squared error             31.9788 %
Total Number of Instances              210     
=== Detailed Accuracy By Class ===
TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
0.929    0.036    0.929      0.929    0.929      0.893    0.993     0.987     Kama
1.000    0.021    0.959      1.000    0.979      0.969    0.999     0.999     Rosa 
0.929    0.014    0.970      0.929    0.949      0.925    0.996     0.992   Canadian
Weighted Avg.    
0.952    0.024    0.953      0.952    0.952      0.929    0.996     0.993     
=== Confusion Matrix ===
 a  b  c   <-- classified as
65  3  2 |  a = Kama
 0 70  0 |  b = Rosa 
 5  0 65 |  c = Canadian
